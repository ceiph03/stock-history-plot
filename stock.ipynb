# %%
import finance
import pandas as pd
import yfinance as yf
from datetime import datetime
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(font_scale=1.0)

# %%
freq = 'M' #'M' -monthly investment, 'W' - weekly investment
start = datetime(2015,3,1) # Define starting day
end = datetime(2023,8,1) #Define ending day
instances = []
tickers = ['tqqq','soxl'] #Provide ticker names you want to plot and calculate ROI.
for ticker in tickers:
    instance = finance.Stock(ticker,start,end).invest(freq)
    instances.append(instance)
finance.Stock.plot(instances)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (<Figure size 1200x900 with 4 Axes>,
#  array([<Axes: xlabel='Date', ylabel='ROI [%]'>,
#         <Axes: xlabel='Date', ylabel='Price change [%]'>, <Axes: >],
#        dtype=object),
#                          tqqq        soxl
#  cum_ROI (%)       293.340546  380.741180
#  price change (%)  781.027710  913.805725)
